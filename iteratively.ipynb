# %%
import numpy as np
from numpy.linalg import norm
import scipy
import time 
import pandas as pd
from scipy.optimize import nnls
import matplotlib.pyplot as plt
import scipy.sparse.linalg

# %% [markdown]
# # Basic functions

# %%
def mus(n, a=-1, b=1):
    return np.array([(b ** (k + 1) - a ** (k + 1)) / (k + 1) for k in range(n)], dtype=float)def x_matrix(K, xs):
    return np.array([xs ** k for k in range(K)], dtype=float)def wxks(n, xs, ws):
    return np.array([np.dot(ws, xs ** k) for k in range(n)], dtype=float)def f(point, a=-1, b=1):
    n = point.shape[0]
    m = n // 2
    xs = point[:m]
    ws = point[m:]
    residual = mus(n, a, b) - wxks(n, xs, ws)
    return float(residual @ residual)def grad_x(point, a=-1, b=1):
    n = point.shape[0]
    m = n // 2
    xs = point[:m]
    ws = point[m:]    result = np.zeros(n, dtype=float)
    residual = mus(n, a, b) - wxks(n, xs, ws)    for j in range(m):
        for k in range(1, n):
            result[j] += -2.0 * residual[k] * ws[j] * k * (xs[j] ** (k - 1))    return resultdef grad_w(point, a=-1, b=1):
    n = point.shape[0]
    m = n // 2
    xs = point[:m]
    ws = point[m:]    result = np.zeros(n, dtype=float)
    residual = mus(n, a, b) - wxks(n, xs, ws)    for j in range(m):
        for k in range(n):
            result[m + j] += -2.0 * residual[k] * (xs[j] ** k)    return resultdef grad_f(point, a=-1, b=1):
    return grad_x(point, a, b) + grad_w(point, a, b)

# %% [markdown]
# # Projection matrix of active set

# %%
def epsilon_inactive(x, epsilon, a=-1, b=1):
    n = x.shape[0]
    m = n // 2
    xs = x[:m]
    ws = x[m:]    x_inactive = (xs > a + epsilon) & (xs < b - epsilon)
    w_inactive = ws > epsilon
    mask = np.concatenate([x_inactive, w_inactive]).astype(float)
    return np.diag(mask)def epsilon_active(x, epsilon, a=-1, b=1):
    inactive = epsilon_inactive(x, epsilon, a, b)
    return np.eye(inactive.shape[0]) - inactive

# %% [markdown]
# # Algorithms in 5.5.3

# %%
def project(point, a=-1, b=1):
    n = point.shape[0]
    m = n // 2
    xs = np.clip(point[:m], a, b)
    ws = np.maximum(point[m:], 0.0)
    return np.concatenate([xs, ws], axis=0)def project_line_search(point, p, c1=1e-4, shrink=0.5):
    alpha = 1.0
    f0 = f(point)    while alpha > 1e-12:
        candidate = project(point + alpha * p)
        step = candidate - point
        if f(candidate) <= f0 - c1 * np.dot(step, step) / alpha:
            return alpha
        alpha *= shrink    return 0.0def bfgsrec(n, sks, yks, H0, d):
    q = d.copy()
    alphas = []    for i in range(n - 1, -1, -1):
        sty = float(np.dot(sks[i], yks[i]))
        if sty <= 1e-14:
            alphas.append(0.0)
            continue
        rho = 1.0 / sty
        alpha = rho * np.dot(sks[i], q)
        q = q - alpha * yks[i]
        alphas.append(alpha)    r = H0 @ q    for i in range(n):
        sty = float(np.dot(sks[i], yks[i]))
        if sty <= 1e-14:
            continue
        rho = 1.0 / sty
        beta = rho * np.dot(yks[i], r)
        r = r + sks[i] * (alphas[n - 1 - i] - beta)    return rdef bfgsrecb(n, sks, yks, A0, d, pI):
    return pI @ bfgsrec(n, sks, yks, A0, pI @ d)def bfgsoptb(x, tau_a=1e-12, tau_r=1e-12, grad=grad_f, maxiter=1000, max_history=25):
    x = project(x.astype(float))
    pg0 = x - project(x - grad(x))
    pg_norm0 = norm(pg0)    sks = []
    yks = []
    F = [f(x)]    for _ in range(maxiter):
        g = grad(x)
        pg = x - project(x - g)
        pg_norm = norm(pg)        if pg_norm <= tau_a + tau_r * max(1.0, pg_norm0):
            break        epsilon = min(1.0, pg_norm)
        pI = epsilon_inactive(x, epsilon)        gI = pI @ g
        if sks:
            d = -bfgsrec(len(sks), sks, yks, pI, gI)
        else:
            d = -gI        d = pI @ d
        if norm(d) <= 1e-14:
            d = -pg        alpha = project_line_search(x, d)
        if alpha == 0.0:
            break        x_new = project(x + alpha * d)
        g_new = grad(x_new)        pg_new = x_new - project(x_new - g_new)
        epsilon_new = min(1.0, norm(pg_new))
        pI_new = epsilon_inactive(x_new, epsilon_new)        s = pI_new @ (x_new - x)
        y = pI_new @ (g_new - g)        if np.dot(s, y) > 1e-12 * norm(s) * norm(y):
            sks.append(s)
            yks.append(y)
            if len(sks) > max_history:
                sks.pop(0)
                yks.pop(0)
        else:
            sks.clear()
            yks.clear()        x = x_new
        F.append(f(x))    return x, F

# %% [markdown]
# # Use bfgsoptb in an alternative manner

# %%
def alternative_ls(xs):
    n = xs.shape[0]
    xm = x_matrix(2*n, xs)
    it = 0
    while True:
        it += 1
        ws = nnls(xm, mus(2*n))[0]
        point = np.concatenate([xs, ws])
        point_proposed = bfgsoptb(point, grad=grad_x)[0]
        if f(point_proposed) <= 1e-15:
            break        
        xs = point_proposed[:n]
        xm = x_matrix(2*n, xs)    return point[:n], point[n:]

# %% [markdown]
# # My own implementation of projected bfgs (without using recursion)

# %%
def bfgs(x0, grad=grad_f, maxiter=None):
    if maxiter is None:
        maxiter = 1000
    x_opt, _ = bfgsoptb(x0, grad=grad, maxiter=maxiter)
    return x_opt

# %% [markdown]
# # Using bfgs to optimize (xs,ws) as a whole

# %%
n = 10
xs = np.linspace(-1, 1, n)
ws = np.ones(n)
point = np.concatenate([xs, ws])
res_bfgs = bfgs(point)
f(res_bfgs), res_bfgs

# %% [markdown]
# # Using iterative bfgs in an alternative manner

# %%
def alternative_ls_(xs):
    n = xs.shape[0]
    xm = x_matrix(2*n, xs)
    it = 0
    while True:
        it += 1
        ws = nnls(xm, mus(2*n))[0]
        point = np.concatenate([xs, ws])
        point_proposed = bfgs(point, grad=grad_x)
        if f(point_proposed) <= 1e-15:
            break        if it >= 100:
            break        xs = point_proposed[:n]
        xm = x_matrix(2*n, xs)    return point[:n], point[n:]

# %%
n = 5
xs = np.linspace(-1, 1, n)
ws = np.ones(n)
t1 = time.time()
res = alternative_ls_(xs)
print(time.time() - t1)
print(res)
